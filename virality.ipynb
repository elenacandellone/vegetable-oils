# %%
from src.utils import *
from src.virality import *

# %%
hashtags = []
IETs = []
IET_errs = []
res = {}
for oil in ['coconut','olive','palm']:
    l, res[oil], IET, IET_err = iet(oil)
    hashtags.append(l)
    IETs.append(IET)
    IET_errs.append(IET_err)

# %%
hashtags = []
CSs = []
CS_errs = []

res_cs = {}
for oil in ['coconut','olive','palm']:
    l, res_cs[oil], CS, CS_err = cs(oil)
    hashtags.append(l)
    CSs.append(CS)
    CS_errs.append(CS_err)

# %%
for oil in ['coconut','olive','palm']:
    print(f'{oil}-IET')
    display(res[oil].reset_index(drop=True))
    print(f'{oil}-CS')
    display(res_cs[oil].reset_index(drop=True))
# Out:
# coconut-IET
#       hashtag best distribution       n             p      x_min         D  \
# 0  coconutoil               pwl  139095  9.933264e-01   3.749167  0.022641
# 1     coconut     truncated pwl   90807  3.925366e-02   3.478611  0.026674
# 2      health     truncated pwl   56021  2.980765e-01   9.641944  0.012145
# 3         win     truncated pwl   54546  2.441739e-07   1.456667  0.016146
# 4    giveaway     truncated pwl   39326  0.000000e+00   0.827500  0.034912
# 5         oil               pwl   28054  9.999998e-01  54.913333  0.028485
# 6     organic               pwl   27117  9.970268e-01  14.720833  0.011221
# 7      beauty     truncated pwl   26992  4.591587e-01  31.517500  0.024309
# 8    skincare               pwl   24187  9.983246e-01  35.772778  0.033378
# 9       vegan     truncated pwl   14377  8.483301e-01  20.798333  0.014832
#
#           k     sigma
# 0  2.713764  0.026593
# 1  2.522290  0.018142
# 2  2.525139  0.034879
# 3  1.869960  0.009952
# ...
